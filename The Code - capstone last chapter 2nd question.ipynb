# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe


# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
import folium # map rendering library
from folium import plugins

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# import k-means from clustering stage
from sklearn.cluster import KMeans



print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.19.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  25.55 MB/s
# geopy-1.19.0-p 100% |################################| Time: 0:00:00  10.47 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Libraries imported.

# %%
# Shenton Way, District 01, Singapore
address = 'Mccallum Street, Singapore'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore home are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.19.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Singapore home are 1.2792423, 103.8481312.

# %%
neighborhood_latitude=1.2792655
neighborhood_longitude=103.8480938

# %%
CLIENT_ID = 'G1LIJ4IQ3IPJK20G0TRZIMC145SZWKFKCPCAKEVTEYQ1MMAZ' # your Foursquare ID
CLIENT_SECRET = 'YS5NPIDD1RQHRA1IIAH121SWBTO1RQZPJXXJVPVHJTLANQJR' # your Foursquare Secret
VERSION = '20190421' # Foursquare API version

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=G1LIJ4IQ3IPJK20G0TRZIMC145SZWKFKCPCAKEVTEYQ1MMAZ&client_secret=YS5NPIDD1RQHRA1IIAH121SWBTO1RQZPJXXJVPVHJTLANQJR&v=20190421&ll=1.2792655,103.8480938&radius=500&limit=100'

# %%
# results display is hidden for report simplification 
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cbcbdb4351e3d3ef343c8fc'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51b49e49abd88dd0b4e7330f-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'primary': True,
#          'shortName': 'Wine Bar'}],
#        'id': '51b49e49abd88dd0b4e7330f',
#        'location': {'address': '206 Telok Ayer Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 112,
#         'formattedAddress': ['206 Telok Ayer Street', '068641', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2799249387439204,
#           'lng': 103.84733300574288}],
#         'lat': 1.2799249387439204,
#         'lng': 103.84733300574288,
#         'neighborhood': 'Tanjong Pagar',
#         'postalCode': '068641'},
#        'name': 'Napoleon Food & Wine Bar',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58378307'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-586a792404aa4f25645e4e4e-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '586a792404aa4f25645e4e4e',
#        'location': {'address': '52A Amoy Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 169,
#         'formattedAddress': ['52A Amoy Street', '069878', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801354244146959,
#           'lng': 103.84684430802805}],
#         'lat': 1.2801354244146959,
#         'lng': 103.84684430802805,
#         'postalCode': '069878'},
#        'name': 'Native',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56e9512acd10cabb2f042d09-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'primary': True,
#          'shortName': 'Beer Garden'}],
#        'id': '56e9512acd10cabb2f042d09',
#        'location': {'address': '21A Boon Tat Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 226,
#         'formattedAddress': ['21A Boon Tat Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812544915596238,
#           'lng': 103.8485128808929}],
#         'lat': 1.2812544915596238,
#         'lng': 103.8485128808929},
#        'name': 'Freehouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55a49050498e801fbf03be73-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'primary': True,
#          'shortName': 'Deli / Bodega'}],
#        'id': '55a49050498e801fbf03be73',
#        'location': {'address': '179 Telok Ayer St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Amoy St',
#         'distance': 112,
#         'formattedAddress': ['179 Telok Ayer St (Amoy St)',
#          '068627',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2798723608759432,
#           'lng': 103.84728710112705}],
#         'lat': 1.2798723608759432,
#         'lng': 103.84728710112705,
#         'neighborhood': 'Chinatown',
#         'postalCode': '068627'},
#        'name': 'Park Bench Deli',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50095587e4b078f59fa0aa8e-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '50095587e4b078f59fa0aa8e',
#        'location': {'address': '44 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 184,
#         'formattedAddress': ['44 Amoy Street', '069870', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804615934724815,
#           'lng': 103.84695041484888}],
#         'lat': 1.2804615934724815,
#         'lng': 103.84695041484888,
#         'postalCode': '069870'},
#        'name': "Matt's | The Chocolate Shop",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c57877d6201e21e49b7e86e-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4c57877d6201e21e49b7e86e',
#        'location': {'address': '45 Ann Siang Hill #02-02',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Ann Siang Hill Park',
#         'distance': 243,
#         'formattedAddress': ['45 Ann Siang Hill #02-02 (Ann Siang Hill Park)',
#          '069719',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804684376763578,
#           'lng': 103.8462642876152}],
#         'lat': 1.2804684376763578,
#         'lng': 103.8462642876152,
#         'neighborhood': 'Chinatown',
#         'postalCode': '069719'},
#        'name': 'PS.Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b305537f964a520fef824e3-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '4b305537f964a520fef824e3',
#        'location': {'address': '7 Maxwell Rd',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Telok Ayer St / Amoy St',
#         'distance': 113,
#         'formattedAddress': ['7 Maxwell Rd (Telok Ayer St / Amoy St)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2793678520661573,
#           'lng': 103.84707897656013}],
#         'lat': 1.2793678520661573,
#         'lng': 103.84707897656013,
#         'neighborhood': 'Financial District',
#         'postalCode': '069111'},
#        'name': 'Amoy Street Food Centre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e5e1aefe4cdfc603ed5c7c3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '4e5e1aefe4cdfc603ed5c7c3',
#        'location': {'address': '98 Amoy St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 239,
#         'formattedAddress': ['98 Amoy St', '069918', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281345203093981,
#           'lng': 103.84755092069813}],
#         'lat': 1.281345203093981,
#         'lng': 103.84755092069813,
#         'postalCode': '069918'},
#        'name': '왕대박 Wang Dae Bak Korean BBQ Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56d3c557cd10357fe7eb429e-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '56d3c557cd10357fe7eb429e',
#        'location': {'address': '123 Telok Ayer Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 227,
#         'formattedAddress': ['123 Telok Ayer Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812992606038325,
#           'lng': 103.84793164085784}],
#         'lat': 1.2812992606038325,
#         'lng': 103.84793164085784},
#        'name': 'Magal BBQ 마포갈매기',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56ecb93dcd101850ebc08dc5-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '56ecb93dcd101850ebc08dc5',
#        'location': {'address': '77 Robinson Road #01-03',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 161,
#         'formattedAddress': ['77 Robinson Road #01-03', '068896', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2778141065087054,
#           'lng': 103.84818781617354}],
#         'lat': 1.2778141065087054,
#         'lng': 103.84818781617354,
#         'postalCode': '068896'},
#        'name': 'Mellower Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50248ddde4b0bb3db3a6ff8a-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '50248ddde4b0bb3db3a6ff8a',
#        'location': {'address': '#02-102, Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Rd.',
#         'distance': 154,
#         'formattedAddress': ['#02-102, Amoy Street Food Centre (7 Maxwell Rd.)',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279371,
#           'lng': 103.84671}],
#         'lat': 1.279371,
#         'lng': 103.84671},
#        'name': 'Pepper Bowl',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bab10b9364d97002cc5e458-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'primary': True,
#          'shortName': 'Burritos'}],
#        'id': '5bab10b9364d97002cc5e458',
#        'location': {'address': '#01-01 Frasers Tower',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '182 Cecil Street',
#         'distance': 120,
#         'formattedAddress': ['#01-01 Frasers Tower (182 Cecil Street)',
#          '069547',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790721332821124,
#           'lng': 103.84702556749504}],
#         'lat': 1.2790721332821124,
#         'lng': 103.84702556749504,
#         'neighborhood': 'Financial District',
#         'postalCode': '069547'},
#        'name': 'Muchachos',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-543e53f6498e8eacbba09d5e-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '543e53f6498e8eacbba09d5e',
#        'location': {'address': '182 Telok Ayer Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 149,
#         'formattedAddress': ['182 Telok Ayer Street', '068630', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280479036515832,
#           'lng': 103.84752160405156}],
#         'lat': 1.280479036515832,
#         'lng': 103.84752160405156,
#         'neighborhood': 'Chinatown',
#         'postalCode': '068630'},
#        'name': 'Oven & Fried Chicken',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f704af9e4b07a4bc6edd2a9-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4f704af9e4b07a4bc6edd2a9',
#        'location': {'address': '35 Robinson Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 219,
#         'formattedAddress': ['35 Robinson Road', '068876', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280123733393359,
#           'lng': 103.84986688322}],
#         'lat': 1.280123733393359,
#         'lng': 103.84986688322,
#         'postalCode': '068876'},
#        'name': 'Sofitel So Singapore',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '150895632'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59256e0228122f403d2959ab-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'primary': True,
#          'shortName': 'Modern European'}],
#        'id': '59256e0228122f403d2959ab',
#        'location': {'address': '72 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 186,
#         'formattedAddress': ['72 Amoy Street', '069893', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802674,
#           'lng': 103.84675}],
#         'lat': 1.2802674,
#         'lng': 103.84675,
#         'postalCode': '069893'},
#        'name': 'Nouri',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a0a815ab546184394622ff6-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '5a0a815ab546184394622ff6',
#        'location': {'address': '11/12 Stanley Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 121,
#         'formattedAddress': ['11/12 Stanley Street', '068734', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2803394109655468,
#           'lng': 103.8478881267848}],
#         'lat': 1.2803394109655468,
#         'lng': 103.8478881267848,
#         'postalCode': '068734',
#         'state': 'Singapore'},
#        'name': 'Common Man Stan',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e741c8baeb780be09a0321f-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4e741c8baeb780be09a0321f',
#        'location': {'address': '136 Telok Ayer St',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 251,
#         'formattedAddress': ['136 Telok Ayer St', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2815286862041824,
#           'lng': 103.84811698897273}],
#         'lat': 1.2815286862041824,
#         'lng': 103.84811698897273},
#        'name': 'Sarnies',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ca579c7d971b1f7593ef7e0-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'primary': True,
#          'shortName': 'Soup'}],
#        'id': '4ca579c7d971b1f7593ef7e0',
#        'location': {'address': '#02-129, Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Road',
#         'distance': 167,
#         'formattedAddress': ['#02-129, Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794006,
#           'lng': 103.846596}],
#         'lat': 1.2794006,
#         'lng': 103.846596,
#         'neighborhood': 'Financial District',
#         'postalCode': '069111'},
#        'name': 'Han Kee Fish Soup',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53db460f498e18a343d830db-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '53db460f498e18a343d830db',
#        'location': {'address': '198 Telok Ayer St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 134,
#         'formattedAddress': ['198 Telok Ayer St', '068637', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280137,
#           'lng': 103.847256}],
#         'lat': 1.280137,
#         'lng': 103.847256,
#         'postalCode': '068637'},
#        'name': 'Pantler',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6a6236f964a5200fd42be3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b6a6236f964a5200fd42be3',
#        'location': {'address': '#02-78 Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Road',
#         'distance': 158,
#         'formattedAddress': ['#02-78 Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2795293,
#           'lng': 103.846695}],
#         'lat': 1.2795293,
#         'lng': 103.846695,
#         'postalCode': '069111'},
#        'name': 'Coffee Break',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-551bd574498e5f30136a811e-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '551bd574498e5f30136a811e',
#        'location': {'address': '19 Boon Tat Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 229,
#         'formattedAddress': ['19 Boon Tat Street', '069619', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812964408600642,
#           'lng': 103.8484369192239}],
#         'lat': 1.2812964408600642,
#         'lng': 103.8484369192239,
#         'postalCode': '069619'},
#        'name': 'FYR Cycene Ond Drinc',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-511b32ade4b028f8d3314584-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '511b32ade4b028f8d3314584',
#        'location': {'address': '#01-39 Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Rd',
#         'distance': 165,
#         'formattedAddress': ['#01-39 Amoy Street Food Centre (7 Maxwell Rd)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2793912,
#           'lng': 103.84661}],
#         'lat': 1.2793912,
#         'lng': 103.84661,
#         'neighborhood': 'Financial District',
#         'postalCode': '069111'},
#        'name': 'a noodle story',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b13fe99f964a520659b23e3-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '4b13fe99f964a520659b23e3',
#        'location': {'address': '18 Raffles Quay',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '1 Boon Tat St.',
#         'distance': 299,
#         'formattedAddress': ['18 Raffles Quay (1 Boon Tat St.)',
#          '048582',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2805818978847052,
#           'lng': 103.85044020580223}],
#         'lat': 1.2805818978847052,
#         'lng': 103.85044020580223,
#         'postalCode': '048582'},
#        'name': 'Lau Pa Sat Festival Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5580f23c498ed3f5a3270457-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '5580f23c498ed3f5a3270457',
#        'location': {'address': '52 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 170,
#         'formattedAddress': ['52 Amoy Street', '069878', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801395970080391,
#           'lng': 103.84683438697066}],
#         'lat': 1.2801395970080391,
#         'lng': 103.84683438697066,
#         'postalCode': '069878'},
#        'name': "Wanton Seng's Noodle Bar",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58181cfd38fa17eb24ba32fa-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '58181cfd38fa17eb24ba32fa',
#        'location': {'address': '#06-01 Tanjong Pagar Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Wallich Street',
#         'distance': 307,
#         'formattedAddress': ['#06-01 Tanjong Pagar Centre (7 Wallich Street)',
#          '078884',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770546200166835,
#           'lng': 103.84643542061019}],
#         'lat': 1.2770546200166835,
#         'lng': 103.84643542061019,
#         'postalCode': '078884'},
#        'name': 'Virgin Active',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54e975f6498e0c8bb883ee29-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'primary': True,
#          'shortName': 'Southern / Soul'}],
#        'id': '54e975f6498e0c8bb883ee29',
#        'location': {'address': '167 Telok Ayer Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 129,
#         'formattedAddress': ['167 Telok Ayer Street', '068620', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802049410855447,
#           'lng': 103.8474104901937}],
#         'lat': 1.2802049410855447,
#         'lng': 103.8474104901937,
#         'postalCode': '068620'},
#        'name': 'Meat Smith',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '219625364'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-557a6b3c498ed9cb15987433-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '557a6b3c498ed9cb15987433',
#        'location': {'address': '8 Stanley Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 101,
#         'formattedAddress': ['8 Stanley Street', '068727', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280110799343203,
#           'lng': 103.8477615067585}],
#         'lat': 1.280110799343203,
#         'lng': 103.8477615067585,
#         'postalCode': '068727'},
#        'name': 'ShuKuu Izakaya',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51407e7fe4b084291b552e1d-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '51407e7fe4b084291b552e1d',
#        'location': {'address': '73 Amoy St, Second Floor',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 172,
#         'formattedAddress': ['73 Amoy St, Second Floor', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280207345376872,
#           'lng': 103.84686000197097}],
#         'lat': 1.280207345376872,
#         'lng': 103.84686000197097},
#        'name': 'The Spiffy Dapper',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '51342112'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51245408e4b07c9613693ff3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '51245408e4b07c9613693ff3',
#        'location': {'address': '92 Amoy Street #01-02',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 246,
#         'formattedAddress': ['92 Amoy Street #01-02', '069911', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812406376693863,
#           'lng': 103.8471001202725}],
#         'lat': 1.2812406376693863,
#         'lng': 103.8471001202725,
#         'postalCode': '069911'},
#        'name': 'The Flying Squirrel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c2c98f8bbda6c871fa0bcc-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '51c2c98f8bbda6c871fa0bcc',
#        'location': {'address': 'Asia Square Tower 2, 12 Marina View',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 317,
#         'formattedAddress': ['Asia Square Tower 2, 12 Marina View',
#          '018961',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2782748644512303,
#           'lng': 103.85077194308906}],
#         'lat': 1.2782748644512303,
#         'lng': 103.85077194308906,
#         'postalCode': '018961',
#         'state': 'SG-01'},
#        'name': 'The Westin Singapore',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63746181'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-559bcec1498ef1434e22b3c6-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '559bcec1498ef1434e22b3c6',
#        'location': {'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 237,
#         'formattedAddress': ['Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2813980779857868,
#           'lng': 103.84816324142832}],
#         'lat': 1.2813980779857868,
#         'lng': 103.84816324142832},
#        'name': "L'Operetta Corner Bar",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fc8aecee4b08eb1f57a1a81-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4fc8aecee4b08eb1f57a1a81',
#        'location': {'address': '1 Shenton Way',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 227,
#         'formattedAddress': ['1 Shenton Way', '068803', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790836483039665,
#           'lng': 103.85012677894278}],
#         'lat': 1.2790836483039665,
#         'lng': 103.85012677894278,
#         'neighborhood': 'Financial District',
#         'postalCode': '068803'},
#        'name': 'Anglo Indian Cafe & Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52d1228d498ede513b7886e9-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '52d1228d498ede513b7886e9',
#        'location': {'address': '73 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 190,
#         'formattedAddress': ['73 Amoy Street', '069892', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280276,
#           'lng': 103.846707}],
#         'lat': 1.280276,
#         'lng': 103.846707,
#         'postalCode': '069892'},
#        'name': 'Dapper Coffee',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '135236704'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d24773df39ca14334e675b8-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4d24773df39ca14334e675b8',
#        'location': {'address': '#01-56/57 7 Maxwell Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 80,
#         'formattedAddress': ['#01-56/57 7 Maxwell Road',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2791000736241216,
#           'lng': 103.84739222011355}],
#         'lat': 1.2791000736241216,
#         'lng': 103.84739222011355,
#         'postalCode': '069111'},
#        'name': 'Quan Ji @ Amoy Street Food Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-561b46b7498efd3d5732c7e3-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '5bae9231bedf3950379f89d4',
#          'name': 'Poke Place',
#          'pluralName': 'Poke Places',
#          'primary': True,
#          'shortName': 'Poke Place'}],
#        'id': '561b46b7498efd3d5732c7e3',
#        'location': {'address': '92 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 224,
#         'formattedAddress': ['92 Amoy Street', '069911', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2811460874003433,
#           'lng': 103.8473642206596}],
#         'lat': 1.2811460874003433,
#         'lng': 103.8473642206596,
#         'postalCode': '069911'},
#        'name': 'Aloha Poké',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bd69fbbe55d8b002ccf6f9f-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'primary': True,
#          'shortName': 'Cupcakes'}],
#        'id': '5bd69fbbe55d8b002ccf6f9f',
#        'location': {'address': '134 Telok Ayer Street',
#         'cc': 'SG',
#         'city': 'Tanjong Pagar',
#         'country': 'Singapore',
#         'distance': 256,
#         'formattedAddress': ['134 Telok Ayer Street', '068600', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2815704412598685,
#           'lng': 103.84814227270866}],
#         'lat': 1.2815704412598685,
#         'lng': 103.84814227270866,
#         'postalCode': '068600',
#         'state': 'Singapore'},
#        'name': 'Plain Vanilla',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-506daac8e4b09e74d871828c-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'primary': True,
#          'shortName': 'Spanish'}],
#        'id': '506daac8e4b09e74d871828c',
#        'location': {'address': '22 Ann Siang Hill',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Ann Siang Road',
#         'distance': 330,
#         'formattedAddress': ['22 Ann Siang Hill (Ann Siang Road)',
#          '069702',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810338519455675,
#           'lng': 103.84570753754707}],
#         'lat': 1.2810338519455675,
#         'lng': 103.84570753754707,
#         'postalCode': '069702'},
#        'name': 'Lolla',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55dd3b2f498ee2d1c9ec32ec-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '55dd3b2f498ee2d1c9ec32ec',
#        'location': {'address': '#01-01/02/03, CapitaGreen',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '138 Market Street',
#         'distance': 327,
#         'formattedAddress': ['#01-01/02/03, CapitaGreen (138 Market Street)',
#          '048946',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281468,
#           'lng': 103.850039}],
#         'lat': 1.281468,
#         'lng': 103.850039,
#         'postalCode': '048946'},
#        'name': 'Grain Traders',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-553b2460498e8cfc0a3cdc32-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '553b2460498e8cfc0a3cdc32',
#        'location': {'address': '15 Ann Siang Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 330,
#         'formattedAddress': ['15 Ann Siang Road', '069695', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810744259693214,
#           'lng': 103.84574260981839}],
#         'lat': 1.2810744259693214,
#         'lng': 103.84574260981839,
#         'postalCode': '069695'},
#        'name': 'Yen Yakiniku',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b05880bf964a520eaad22e3-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b05880bf964a520eaad22e3',
#        'location': {'address': '33 Erskine Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 336,
#         'formattedAddress': ['33 Erskine Road', '069333', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2807069667371653,
#           'lng': 103.84543116452546}],
#         'lat': 1.2807069667371653,
#         'lng': 103.84543116452546,
#         'postalCode': '069333'},
#        'name': 'The Scarlet',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52c54d0411d2a3d73dae49f6-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'primary': True,
#          'shortName': 'Street Food Gathering'}],
#        'id': '52c54d0411d2a3d73dae49f6',
#        'location': {'address': 'Boon Tat Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 306,
#         'formattedAddress': ['Boon Tat Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802855829763509,
#           'lng': 103.85065465718189}],
#         'lat': 1.2802855829763509,
#         'lng': 103.85065465718189},
#        'name': 'Lau Pa Sat Satay Street',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-511f6ad6e4b016a06dc7bf33-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '511f6ad6e4b016a06dc7bf33',
#        'location': {'address': '208 Telok Ayer St.',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 113,
#         'formattedAddress': ['208 Telok Ayer St.', '068642', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279885316738616,
#           'lng': 103.84728844184724}],
#         'lat': 1.279885316738616,
#         'lng': 103.84728844184724,
#         'postalCode': '068642'},
#        'name': 'The Market Grill',
#        'photos': {'count': 0, 'groups': []}}},
# ...
#          'shortName': 'Sushi'}],
#        'id': '592033c1f96b2c5570007df6',
#        'location': {'address': 'Capital Tower #01-10',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 250,
#         'formattedAddress': ['Capital Tower #01-10', '068912', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770746709229392,
#           'lng': 103.84757986038572}],
#         'lat': 1.2770746709229392,
#         'lng': 103.84757986038572,
#         'postalCode': '068912'},
#        'name': 'En Sakaba',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57457264498ee0e20fb42b3b-87',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'primary': True,
#          'shortName': 'Beer Bar'}],
#        'id': '57457264498ee0e20fb42b3b',
#        'location': {'address': '#01-33, Maxwell Food Center',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '1 Kadayanallur Street',
#         'distance': 377,
#         'formattedAddress': ['#01-33, Maxwell Food Center (1 Kadayanallur Street)',
#          '069184',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802459085809665,
#           'lng': 103.84485033931811}],
#         'lat': 1.2802459085809665,
#         'lng': 103.84485033931811,
#         'neighborhood': 'Financial District',
#         'postalCode': '069184'},
#        'name': '3rd Culture Brewing Co.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a73e804f964a52099dd1fe3-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a3e',
#          'name': 'Buddhist Temple',
#          'pluralName': 'Buddhist Temples',
#          'primary': True,
#          'shortName': 'Buddhist Temple'}],
#        'id': '4a73e804f964a52099dd1fe3',
#        'location': {'address': '288 South Bridge Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'South Bridge Road / Sago Lane',
#         'distance': 479,
#         'formattedAddress': ['288 South Bridge Road (South Bridge Road / Sago Lane)',
#          '058840',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2813909441671445,
#           'lng': 103.84434789419174}],
#         'lat': 1.2813909441671445,
#         'lng': 103.84434789419174,
#         'postalCode': '058840'},
#        'name': 'Buddha Tooth Relic Temple & Museum (新加坡佛牙寺龙华院)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a7a977c872f7d3916e199f9-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5a7a977c872f7d3916e199f9',
#        'location': {'address': 'Hong Leong Building',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '#01-08',
#         'distance': 343,
#         'formattedAddress': ['Hong Leong Building (#01-08)', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2811961463460806,
#           'lng': 103.85050239068553}],
#         'lat': 1.2811961463460806,
#         'lng': 103.85050239068553},
#        'name': 'Alchemist',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57831d2b498eb7aacd46454b-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'id': '57831d2b498eb7aacd46454b',
#        'location': {'address': '51 Telok Ayer St #01-02',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 427,
#         'formattedAddress': ['51 Telok Ayer St #01-02', '048441', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2829771911083339,
#           'lng': 103.84906805089604}],
#         'lat': 1.2829771911083339,
#         'lng': 103.84906805089604,
#         'postalCode': '048441'},
#        'name': 'Fat Saigon Boy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-519d916f498ea9ac42f23088-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '519d916f498ea9ac42f23088',
#        'location': {'address': '76 Telok Ayer St, Singapore 048464',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 431,
#         'formattedAddress': ['76 Telok Ayer St, Singapore 048464',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2831183226093794,
#           'lng': 103.8485385594228}],
#         'lat': 1.2831183226093794,
#         'lng': 103.8485385594228},
#        'name': 'Amoy Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5925348c747ecd3652b7fc31-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '5925348c747ecd3652b7fc31',
#        'location': {'address': '6A Shenton Way',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 315,
#         'formattedAddress': ['6A Shenton Way', '068815', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.276451814240619,
#           'lng': 103.8484626777089}],
#         'lat': 1.276451814240619,
#         'lng': 103.8484626777089,
#         'postalCode': '068815'},
#        'name': 'Downtown Gallery',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e3f9e6dfa76455375d3f59f-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4e3f9e6dfa76455375d3f59f',
#        'location': {'address': '112 Telok Ayer St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 324,
#         'formattedAddress': ['112 Telok Ayer St', '068581', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.282162723527292,
#           'lng': 103.84842669913324}],
#         'lat': 1.282162723527292,
#         'lng': 103.84842669913324,
#         'postalCode': '068581'},
#        'name': 'The Muffinry',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d6b9a124395a1cd8620a973-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4d6b9a124395a1cd8620a973',
#        'location': {'address': '#01-25 Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Road',
#         'distance': 98,
#         'formattedAddress': ['#01-25 Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794284177534678,
#           'lng': 103.84722539306422}],
#         'lat': 1.2794284177534678,
#         'lng': 103.84722539306422,
#         'postalCode': '069111'},
#        'name': 'Good Day 好日',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-576d2c5f498e95407d228792-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '576d2c5f498e95407d228792',
#        'location': {'address': '115 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 335,
#         'formattedAddress': ['115 Amoy Street', '069935', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2822729012698946,
#           'lng': 103.84786978392009}],
#         'lat': 1.2822729012698946,
#         'lng': 103.84786978392009,
#         'postalCode': '069935'},
#        'name': 'Ding Dong',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b2b3525cd441c002cfa5f34-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'primary': True,
#          'shortName': 'Wine Bar'}],
#        'id': '5b2b3525cd441c002cfa5f34',
#        'location': {'address': '7-9 Club Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 402,
#         'formattedAddress': ['7-9 Club Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.282742477971281,
#           'lng': 103.84708897443797}],
#         'lat': 1.282742477971281,
#         'lng': 103.84708897443797},
#        'name': 'Merci Marcel Club Street',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-566b5dbc498e50a39a4d4c29-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfdd',
#          'name': 'North Indian Restaurant',
#          'pluralName': 'North Indian Restaurants',
#          'primary': True,
#          'shortName': 'North Indian'}],
#        'id': '566b5dbc498e50a39a4d4c29',
#        'location': {'address': '18 Raffles Quay, #01-96',
#         'cc': 'SG',
#         'city': 'Singapore 048582',
#         'country': 'Singapore',
#         'crossStreet': 'Lau Pa Sat Telok Ayer Festive Market',
#         'distance': 304,
#         'formattedAddress': ['18 Raffles Quay, #01-96 (Lau Pa Sat Telok Ayer Festive Market)',
#          '048582',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802443099838159,
#           'lng': 103.85065019741309}],
#         'lat': 1.2802443099838159,
#         'lng': 103.85065019741309,
#         'neighborhood': 'Financial District',
#         'postalCode': '048582'},
#        'name': 'Urban Roti',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-592a85ba8d0a53502937bbd2-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '592a85ba8d0a53502937bbd2',
#        'location': {'address': '53 Tras Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 432,
#         'formattedAddress': ['53 Tras Street', '078992', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2779778063824219,
#           'lng': 103.84442755714727}],
#         'lat': 1.2779778063824219,
#         'lng': 103.84442755714727,
#         'postalCode': '078992'},
#        'name': 'Nesuto Patisserie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5625d21a498e596424dac931-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5625d21a498e596424dac931',
#        'location': {'address': '#36-01 Capital Tower, 168 Robinson Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 180,
#         'formattedAddress': ['#36-01 Capital Tower, 168 Robinson Road',
#          '068912',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2777145899465967,
#           'lng': 103.84761868252289}],
#         'lat': 1.2777145899465967,
#         'lng': 103.84761868252289,
#         'postalCode': '068912'},
#        'name': 'Joe & Dough',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Financial District, Singapore',
#   'headerLocation': 'Financial District',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 1.2837655045000045,
#     'lng': 103.85258652226942},
#    'sw': {'lat': 1.2747654954999954, 'lng': 103.84360107773058}},
#   'totalResults': 185}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
SGnearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]
# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)
# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.shape
# Out:
# (100, 4)

# %%
SGnearby_venues.head(10)
# Out:
#                                      name         categories       lat  \
# 0                Napoleon Food & Wine Bar           Wine Bar  1.279925
# 1                                  Native       Cocktail Bar  1.280135
# 2                               Freehouse        Beer Garden  1.281254
# 3                         Park Bench Deli      Deli / Bodega  1.279872
# 4             Matt's | The Chocolate Shop       Dessert Shop  1.280462
# 5                                 PS.Cafe               Café  1.280468
# 6                 Amoy Street Food Centre         Food Court  1.279368
# 7  왕대박 Wang Dae Bak Korean BBQ Restaurant  Korean Restaurant  1.281345
# 8                         Magal BBQ 마포갈매기  Korean Restaurant  1.281299
# 9                         Mellower Coffee               Café  1.277814
#
#           lng
# 0  103.847333
# 1  103.846844
# 2  103.848513
# 3  103.847287
# 4  103.846950
# 5  103.846264
# 6  103.847079
# 7  103.847551
# 8  103.847932
# 9  103.848188

# %%
latitude=1.2792655
longitude=103.8480938
# create map of Singapore place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=18)
# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=30,
        radius=7,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.6,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_b0b56a2ea7844c61b4b04e06fc08eed4 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='IQRtR1klXPGJ4xABm_Ka7OcTzLPxKWfo9oou37es82XP',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_b0b56a2ea7844c61b4b04e06fc08eed4.get_object(Bucket='myfirstproject-donotdelete-pr-kv8hgzmkclc58w',Key='mh_neigh_data1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

manhattan_data = pd.read_csv(body)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               2
# 2  Manhattan  Washington Heights  40.851903 -73.936900               4
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0

# %%
body = client_b0b56a2ea7844c61b4b04e06fc08eed4.get_object(Bucket='myfirstproject-donotdelete-pr-kv8hgzmkclc58w',Key='manhattan_merged.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )


manhattan_merged = pd.read_csv(body)
manhattan_merged.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               2
# 2  Manhattan  Washington Heights  40.851903 -73.936900               4
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop        Discount Store           Yoga Studio
# 1    Chinese Restaurant          Cocktail Bar    Dim Sum Restaurant
# 2                  Café                Bakery     Mobile Phone Shop
# 3    Mexican Restaurant                Lounge           Pizza Place
# 4    Mexican Restaurant           Coffee Shop                  Café
#
#   4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0            Steakhouse        Supplement Shop        Tennis Stadium
# 1   American Restaurant  Vietnamese Restaurant    Salon / Barbershop
# 2           Pizza Place         Sandwich Place                  Park
# 3                  Café               Wine Bar                Bakery
# 4         Deli / Bodega            Pizza Place          Liquor Store
#
#   7th Most Common Venue      8th Most Common Venue 9th Most Common Venue  \
# 0            Shoe Store                        Gym                  Bank
# 1          Noodle House                     Bakery       Bubble Tea Shop
# 2                   Gym  Latin American Restaurant      Tapas Restaurant
# 3   American Restaurant                       Park    Frozen Yogurt Shop
# 4     Indian Restaurant           Sushi Restaurant        Sandwich Place
#
#   10th Most Common Venue
# 0     Seafood Restaurant
# 1         Ice Cream Shop
# 2     Mexican Restaurant
# 3     Spanish Restaurant
# 4            Yoga Studio

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558 

kclusters=5
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
  # add markers for rental places to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)    
    
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## kk is the cluster number to explore
kk = 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill           Coffee Shop        Discount Store
# 1             Chinatown    Chinese Restaurant          Cocktail Bar
# 6        Central Harlem    African Restaurant    Seafood Restaurant
# 9             Yorkville           Coffee Shop                   Gym
# 14              Clinton               Theater    Italian Restaurant
# 23                 Soho        Clothing Store              Boutique
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 34         Sutton Place  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards           Coffee Shop    Italian Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0              Yoga Studio            Steakhouse        Supplement Shop
# 1       Dim Sum Restaurant   American Restaurant  Vietnamese Restaurant
# 6        French Restaurant   American Restaurant         Cosmetics Shop
# 9                      Bar    Italian Restaurant       Sushi Restaurant
# 14             Coffee Shop   American Restaurant   Gym / Fitness Center
# 23           Women's Store            Shoe Store            Men's Store
# 26                    Park             Bookstore            Pizza Place
# 34  Furniture / Home Store     Indian Restaurant           Dessert Shop
# 39                   Hotel               Theater    American Restaurant
#
#      6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0           Tennis Stadium            Shoe Store                       Gym
# 1       Salon / Barbershop          Noodle House                    Bakery
# 6       Chinese Restaurant           Event Space              Liquor Store
# 9              Pizza Place    Mexican Restaurant             Deli / Bodega
# 14                   Hotel             Wine Shop                       Spa
# 23  Furniture / Home Store    Italian Restaurant  Mediterranean Restaurant
# 26          Sandwich Place          Burger Joint                      Café
# 34     American Restaurant                Bakery                 Juice Bar
# 39                    Café  Gym / Fitness Center           Thai Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0                   Bank     Seafood Restaurant
# 1        Bubble Tea Shop         Ice Cream Shop
# 6               Beer Bar   Gym / Fitness Center
# 9    Japanese Restaurant                    Pub
# 14                   Gym          Indie Theater
# 23           Art Gallery          Design Studio
# 26         Deli / Bodega           Tennis Court
# 34              Boutique       Sushi Restaurant
# 39            Restaurant                    Gym

# %%
body = client_b0b56a2ea7844c61b4b04e06fc08eed4.get_object(Bucket='myfirstproject-donotdelete-pr-kv8hgzmkclc58w',Key='MH_flats_price.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

mh_rent = pd.read_csv(body)
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94    5.0      3400
# 1   East 97th Street  Upper East Side           3.57    3.0      2100
# 2  West 105th Street  Upper West Side           1.89    4.0      2800
# 3        CARMINE ST.     West Village           3.03    2.0      1650
# 4    171 W 23RD ST.           Chelsea           3.45    2.0      1450
#
#    Rent_Price  Lat  Long
# 0       10000  NaN   NaN
# 1        7500  NaN   NaN
# 2        5300  NaN   NaN
# 3        5000  NaN   NaN
# 4        5000  NaN   NaN

# %%
mh_rent.tail()
# Out:
#                   Address                                Area  Price_per_ft2  \
# 139  200 East 72nd Street                Rental in Lenox Hill           5.15
# 140      50 Murray Street            No fee rental in Tribeca           7.11
# 141  300 East 56th Street       No fee rental in Midtown East           3.87
# 142         1930 Broadway  No fee rental in Central Park West           5.06
# 143    33 West 9th Street         Rental in Greenwich Village           6.67
#
#      Rooms  Area-ft2  Rent_Price  Lat  Long
# 139    3.0      1700        8750  NaN   NaN
# 140    2.0      1223        8700  NaN   NaN
# 141    3.0      2100        8118  NaN   NaN
# 142    2.0      1600        8095  NaN   NaN
# 143    2.0      1500       10000  NaN   NaN

# %%
body = client_b0b56a2ea7844c61b4b04e06fc08eed4.get_object(Bucket='myfirstproject-donotdelete-pr-kv8hgzmkclc58w',Key='MH_rent_latlong.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

mh_rent = pd.read_csv(body)
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94    5.0      3400
# 1   East 97th Street  Upper East Side           3.57    3.0      2100
# 2  West 105th Street  Upper West Side           1.89    4.0      2800
# 3        CARMINE ST.     West Village           3.03    2.0      1650
# 4    171 W 23RD ST.           Chelsea           3.45    2.0      1450
#
#    Rent_Price        Lat       Long
# 0       10000  40.799771 -73.966213
# 1        7500  40.788585 -73.955277
# 2        5300  40.799771 -73.966213
# 3        5000  40.730523 -74.001873
# 4        5000  40.744118 -73.995299

# %%
mh_rent.tail()
# Out:
#                   Address                                Area  Price_per_ft2  \
# 139  200 East 72nd Street                Rental in Lenox Hill           5.15
# 140      50 Murray Street            No fee rental in Tribeca           7.11
# 141  300 East 56th Street       No fee rental in Midtown East           3.87
# 142         1930 Broadway  No fee rental in Central Park West           5.06
# 143    33 West 9th Street         Rental in Greenwich Village           6.67
#
#      Rooms  Area-ft2  Rent_Price        Lat       Long
# 139    3.0      1700        8750  40.769465 -73.960339
# 140    2.0      1223        8700  40.714051 -74.009608
# 141    3.0      2100        8118  40.758216 -73.965190
# 142    2.0      1600        8095  40.772474 -73.981901
# 143    2.0      1500       10000  40.733691 -73.997323

# %%
import seaborn as sns
sns.distplot(mh_rent['Rent_Price'],bins=15)

# %%
import seaborn as sns
sns.distplot(mh_rent['Price_per_ft2'],bins=15)

# %%
sns.boxplot(x='Rooms', y= 'Rent_Price', data=mh_rent)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

map_manhattan_rent = folium.Map(location=[latitude, longitude], zoom_start=12.5)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ ',  '+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan_rent) 
    

map_manhattan_rent
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

# create map with clusters
kclusters=5
map_clusters2 = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters2)

# add markers to map for rental places
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters2)  
    
    # Adds tool to the top right
from folium.plugins import MeasureControl
map_manhattan_rent.add_child(MeasureControl())

# FMeasurement ruler icon to establish distnces on map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_manhattan_rent)

map_clusters2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## kk is the cluster number to explore
kk = 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3               Inwood    Mexican Restaurant                Lounge
# 5       Manhattanville         Deli / Bodega    Italian Restaurant
# 10          Lenox Hill      Sushi Restaurant    Italian Restaurant
# 12     Upper West Side    Italian Restaurant                   Bar
# 16         Murray Hill        Sandwich Place                 Hotel
# 17             Chelsea           Coffee Shop    Italian Restaurant
# 18   Greenwich Village    Italian Restaurant      Sushi Restaurant
# 27            Gramercy    Italian Restaurant            Restaurant
# 29  Financial District           Coffee Shop                 Hotel
# 31                Noho    Italian Restaurant     French Restaurant
# 32        Civic Center  Gym / Fitness Center                Bakery
# 35          Turtle Bay    Italian Restaurant           Coffee Shop
# 36          Tudor City                  Café                  Park
# 38            Flatiron    Italian Restaurant   American Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 3              Pizza Place                           Café
# 5       Seafood Restaurant             Mexican Restaurant
# 10             Coffee Shop           Gym / Fitness Center
# 12                  Bakery  Vegetarian / Vegan Restaurant
# 16     Japanese Restaurant           Gym / Fitness Center
# 17          Ice Cream Shop                         Bakery
# 18       French Restaurant                 Clothing Store
# 27  Thrift / Vintage Store                   Cocktail Bar
# 29                     Gym                      Wine Shop
# 31            Cocktail Bar                      Gift Shop
# 32      Italian Restaurant                   Cocktail Bar
# 35              Steakhouse                       Wine Bar
# 36             Pizza Place             Mexican Restaurant
# 38                     Gym           Gym / Fitness Center
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 3               Wine Bar                         Bakery   American Restaurant
# 5       Sushi Restaurant                    Beer Garden           Coffee Shop
# 10           Pizza Place                   Burger Joint         Deli / Bodega
# 12     Indian Restaurant                    Coffee Shop        Cosmetics Shop
# 16           Coffee Shop             Salon / Barbershop          Burger Joint
# 17             Nightclub                        Theater           Art Gallery
# 18    Chinese Restaurant                           Café     Indian Restaurant
# 27            Bagel Shop                    Coffee Shop           Pizza Place
# 29            Steakhouse                            Bar    Italian Restaurant
# 31             Bookstore                  Grocery Store    Mexican Restaurant
# 32     French Restaurant                 Sandwich Place           Coffee Shop
# 35      Sushi Restaurant                          Hotel          Noodle House
# 36      Greek Restaurant               Sushi Restaurant                 Hotel
# 38           Yoga Studio  Vegetarian / Vegan Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Park    Frozen Yogurt Shop     Spanish Restaurant
# 5     Falafel Restaurant            Bike Trail        Other Nightlife
# 10                   Gym   Sporting Goods Shop        Thai Restaurant
# 12              Wine Bar    Mexican Restaurant       Sushi Restaurant
# 16     French Restaurant                   Bar     Italian Restaurant
# 17    Seafood Restaurant   American Restaurant                  Hotel
# 18                Bakery    Seafood Restaurant      Electronics Store
# 27    Mexican Restaurant         Grocery Store              Wine Shop
# 29           Pizza Place                  Park   Gym / Fitness Center
# 31                 Hotel      Sushi Restaurant            Coffee Shop
# 32                   Gym           Yoga Studio                   Park
# 35     Indian Restaurant   Japanese Restaurant      French Restaurant
# 36         Deli / Bodega                 Diner                Dog Run
# 38        Clothing Store        Cosmetics Shop           Cycle Studio

# %%
body = client_b0b56a2ea7844c61b4b04e06fc08eed4.get_object(Bucket='myfirstproject-donotdelete-pr-kv8hgzmkclc58w',Key='NYC_subway_list.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

mh = pd.read_csv(body)
mh.head()
# Out:
#                      sub_station                              sub_address
# 0  Dyckman Street Subway Station   170 Nagle Ave, New York, NY 10034, USA
# 1       57 Street Subway Station                  New York, NY 10106, USA
# 2                       Broad St                  New York, NY 10005, USA
# 3             175 Street Station  807 W 177th St, New York, NY 10033, USA
# 4                 5 Av and 53 St                  New York, NY 10022, USA

# %%
#  Add columns 'lat'  and 'long' to mh dataframe - with random temporary numbers to get started
sLength = len(mh['sub_station'])
lat = pd.Series(np.random.randn(sLength))
long=pd.Series(np.random.randn(sLength))
mh = mh.assign(lat=lat.values)
mh = mh.assign(long=long.values)

# %%
body = client_b0b56a2ea7844c61b4b04e06fc08eed4.get_object(Bucket='myfirstproject-donotdelete-pr-kv8hgzmkclc58w',Key='MH_subway.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

mhsub1 = pd.read_csv(body)
mhsub1.head()
# Out:
#                      sub_station                              sub_address  \
# 0  Dyckman Street Subway Station   170 Nagle Ave, New York, NY 10034, USA
# 1       57 Street Subway Station                  New York, NY 10106, USA
# 2                       Broad St                  New York, NY 10005, USA
# 3             175 Street Station  807 W 177th St, New York, NY 10033, USA
# 4                 5 Av and 53 St                  New York, NY 10022, USA
#
#          lat       long
# 0  40.861857 -73.924509
# 1  40.764250 -73.954525
# 2  40.730862 -73.987156
# 3  40.847991 -73.939785
# 4  40.764250 -73.954525

# %%
mhsub1.tail()
# Out:
#            sub_station                            sub_address        lat  \
# 71            50 St Br      New York, NY 10019, United States  40.764250
# 72   57 Street Station      New York, NY 10019, United States  40.764250
# 73   23 Street Station      New York, NY 10010, United States  40.730862
# 74    14 Street / 8 Av      New York, NY 10014, United States  40.730862
# 75  MTA New York City   525 11th Ave, New York, NY 10018, USA  40.759809
#
#          long
# 71 -73.954525
# 72 -73.954525
# 73 -73.987156
# 74 -73.987156
# 75 -73.999282

# %%
# map subway stations 
# create map of Manhattan using latitude and longitude values obtain previoulsy via Moninatim geolocator
latitude=40.7308619
longitude=-73.9871558

map_mhsub1 = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_mhsub1) 
map_mhsub1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94    5.0      3400
# 1   East 97th Street  Upper East Side           3.57    3.0      2100
# 2  West 105th Street  Upper West Side           1.89    4.0      2800
# 3        CARMINE ST.     West Village           3.03    2.0      1650
# 4    171 W 23RD ST.           Chelsea           3.45    2.0      1450
#
#    Rent_Price        Lat       Long
# 0       10000  40.799771 -73.966213
# 1        7500  40.788585 -73.955277
# 2        5300  40.799771 -73.966213
# 3        5000  40.730523 -74.001873
# 4        5000  40.744118 -73.995299

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

map_manhattan_rent = folium.Map(location=[latitude, longitude], zoom_start=13.3)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan_rent) 
    
    # add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_manhattan_rent) 
    
    # Adds tool to the top right
from folium.plugins import MeasureControl
map_manhattan_rent.add_child(MeasureControl())

# Measurement ruler icon tool to measure distances in map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_manhattan_rent)

map_manhattan_rent
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Red dots are Subway stations, Blue dots are apartments available for rent, Bubbles are the clusters of venues

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

map_mh_one = folium.Map(location=[latitude, longitude], zoom_start=13.3)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ ', '+mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_mh_one) 
    
    # add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_mh_one) 


# set color scheme for the clusters
kclusters=5
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=15,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_mh_one)

    # Adds tool to the top right
from folium.plugins import MeasureControl
map_mh_one.add_child(MeasureControl())

# Measurement ruler icon tool to measure distances in map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_mh_one)

map_mh_one
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## kk is the cluster number to explore
kk = 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill           Coffee Shop        Discount Store
# 1             Chinatown    Chinese Restaurant          Cocktail Bar
# 6        Central Harlem    African Restaurant    Seafood Restaurant
# 9             Yorkville           Coffee Shop                   Gym
# 14              Clinton               Theater    Italian Restaurant
# 23                 Soho        Clothing Store              Boutique
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 34         Sutton Place  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards           Coffee Shop    Italian Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0              Yoga Studio            Steakhouse        Supplement Shop
# 1       Dim Sum Restaurant   American Restaurant  Vietnamese Restaurant
# 6        French Restaurant   American Restaurant         Cosmetics Shop
# 9                      Bar    Italian Restaurant       Sushi Restaurant
# 14             Coffee Shop   American Restaurant   Gym / Fitness Center
# 23           Women's Store            Shoe Store            Men's Store
# 26                    Park             Bookstore            Pizza Place
# 34  Furniture / Home Store     Indian Restaurant           Dessert Shop
# 39                   Hotel               Theater    American Restaurant
#
#      6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0           Tennis Stadium            Shoe Store                       Gym
# 1       Salon / Barbershop          Noodle House                    Bakery
# 6       Chinese Restaurant           Event Space              Liquor Store
# 9              Pizza Place    Mexican Restaurant             Deli / Bodega
# 14                   Hotel             Wine Shop                       Spa
# 23  Furniture / Home Store    Italian Restaurant  Mediterranean Restaurant
# 26          Sandwich Place          Burger Joint                      Café
# 34     American Restaurant                Bakery                 Juice Bar
# 39                    Café  Gym / Fitness Center           Thai Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0                   Bank     Seafood Restaurant
# 1        Bubble Tea Shop         Ice Cream Shop
# 6               Beer Bar   Gym / Fitness Center
# 9    Japanese Restaurant                    Pub
# 14                   Gym          Indie Theater
# 23           Art Gallery          Design Studio
# 26         Deli / Bodega           Tennis Court
# 34              Boutique       Sushi Restaurant
# 39            Restaurant                    Gym

# %%
## kk is the cluster number to explore
kk = 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3               Inwood    Mexican Restaurant                Lounge
# 5       Manhattanville         Deli / Bodega    Italian Restaurant
# 10          Lenox Hill      Sushi Restaurant    Italian Restaurant
# 12     Upper West Side    Italian Restaurant                   Bar
# 16         Murray Hill        Sandwich Place                 Hotel
# 17             Chelsea           Coffee Shop    Italian Restaurant
# 18   Greenwich Village    Italian Restaurant      Sushi Restaurant
# 27            Gramercy    Italian Restaurant            Restaurant
# 29  Financial District           Coffee Shop                 Hotel
# 31                Noho    Italian Restaurant     French Restaurant
# 32        Civic Center  Gym / Fitness Center                Bakery
# 35          Turtle Bay    Italian Restaurant           Coffee Shop
# 36          Tudor City                  Café                  Park
# 38            Flatiron    Italian Restaurant   American Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 3              Pizza Place                           Café
# 5       Seafood Restaurant             Mexican Restaurant
# 10             Coffee Shop           Gym / Fitness Center
# 12                  Bakery  Vegetarian / Vegan Restaurant
# 16     Japanese Restaurant           Gym / Fitness Center
# 17          Ice Cream Shop                         Bakery
# 18       French Restaurant                 Clothing Store
# 27  Thrift / Vintage Store                   Cocktail Bar
# 29                     Gym                      Wine Shop
# 31            Cocktail Bar                      Gift Shop
# 32      Italian Restaurant                   Cocktail Bar
# 35              Steakhouse                       Wine Bar
# 36             Pizza Place             Mexican Restaurant
# 38                     Gym           Gym / Fitness Center
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 3               Wine Bar                         Bakery   American Restaurant
# 5       Sushi Restaurant                    Beer Garden           Coffee Shop
# 10           Pizza Place                   Burger Joint         Deli / Bodega
# 12     Indian Restaurant                    Coffee Shop        Cosmetics Shop
# 16           Coffee Shop             Salon / Barbershop          Burger Joint
# 17             Nightclub                        Theater           Art Gallery
# 18    Chinese Restaurant                           Café     Indian Restaurant
# 27            Bagel Shop                    Coffee Shop           Pizza Place
# 29            Steakhouse                            Bar    Italian Restaurant
# 31             Bookstore                  Grocery Store    Mexican Restaurant
# 32     French Restaurant                 Sandwich Place           Coffee Shop
# 35      Sushi Restaurant                          Hotel          Noodle House
# 36      Greek Restaurant               Sushi Restaurant                 Hotel
# 38           Yoga Studio  Vegetarian / Vegan Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Park    Frozen Yogurt Shop     Spanish Restaurant
# 5     Falafel Restaurant            Bike Trail        Other Nightlife
# 10                   Gym   Sporting Goods Shop        Thai Restaurant
# 12              Wine Bar    Mexican Restaurant       Sushi Restaurant
# 16     French Restaurant                   Bar     Italian Restaurant
# 17    Seafood Restaurant   American Restaurant                  Hotel
# 18                Bakery    Seafood Restaurant      Electronics Store
# 27    Mexican Restaurant         Grocery Store              Wine Shop
# 29           Pizza Place                  Park   Gym / Fitness Center
# 31                 Hotel      Sushi Restaurant            Coffee Shop
# 32                   Gym           Yoga Studio                   Park
# 35     Indian Restaurant   Japanese Restaurant      French Restaurant
# 36         Deli / Bodega                 Diner                Dog Run
# 38        Clothing Store        Cosmetics Shop           Cycle Studio
